# %%
doc = [
    "Rajiv is a good cricket player",
    "Sanjay is bad chess player"
]
print(doc)
# Out:
# ['Rajiv is a good cricket player', 'Sanjay is bad chess player']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(binary=True)
vectorizer.fit(doc)
# Out:
# CountVectorizer(binary=True)

# %%
bag_matrix = vectorizer.transform(doc)
bag_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 10 stored elements and shape (2, 8)>

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['bad', 'chess', 'cricket', 'good', 'is', 'player', 'rajiv',
#        'sanjay'], dtype=object)

# %%
import pandas as pd
pd.DataFrame(bag_matrix.toarray(),columns = vectorizer.get_feature_names_out())
# Out:
#    bad  chess  cricket  good  is  player  rajiv  sanjay
# 0    0      0        1     1   1       1      1       0
# 1    1      1        0     0   1       1      0       1

# %% [markdown]
# **TF-IDF vectorizer**

# %%
docs = [
    "AI is the future",
    "AI and ML are the future",
    "Physics is an intresting subject",
    "I am intrested in the cocepts of physics"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectorizer.fit(docs)
# Out:
# TfidfVectorizer()

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['ai', 'am', 'an', 'and', 'are', 'cocepts', 'future', 'in',
#        'intrested', 'intresting', 'is', 'ml', 'of', 'physics', 'subject',
#        'the'], dtype=object)

# %%
tf_idf_matrix = vectorizer.transform(docs)

# %%
pd.DataFrame(tf_idf_matrix.toarray() , columns = vectorizer.get_feature_names_out())
# Out:
#          ai        am        an       and       are   cocepts    future  \
# 0  0.523035  0.000000  0.000000  0.000000  0.000000  0.000000  0.523035
# 1  0.365594  0.000000  0.000000  0.463709  0.463709  0.000000  0.365594
# 2  0.000000  0.000000  0.485461  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.407265  0.000000  0.000000  0.000000  0.407265  0.000000
#
#          in  intrested  intresting        is        ml        of   physics  \
# 0  0.000000   0.000000    0.000000  0.523035  0.000000  0.000000  0.000000
# 1  0.000000   0.000000    0.000000  0.000000  0.463709  0.000000  0.000000
# 2  0.000000   0.000000    0.485461  0.382743  0.000000  0.000000  0.382743
# 3  0.407265   0.407265    0.000000  0.000000  0.000000  0.407265  0.321093
#
#     subject       the
# 0  0.000000  0.423442
# 1  0.000000  0.295980
# 2  0.485461  0.000000
# 3  0.000000  0.259952

# %%
text = "I love machine learning. I love NLP and machine learning."

from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Create a frequency dictionary
#word_freq = Counter(' '.join(text).split())
word_freq = Counter(text)

# Generate word cloud
wordcloud = WordCloud(
    width=800,height=400,background_color='white',
    max_words=100,contour_width=3,contour_color='steelblue',
    colormap='viridis').generate_from_frequencies(word_freq)

# %%
# Display
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
